# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# MATPLOT LIB</p>

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(5,3,'ro')
plt.plot(3,2,'bo') #bo is for blue circle
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg #import plotting on canvas
from matplotlib.figure import Figure
fig=Figure()
#associate fig with background
canvas=FigureCanvasAgg(fig)
ax=fig.add_subplot(111) #pass 3 things
#plot th point(3,2)
ax.plot(3,2,'.')
#save the figure to test.png
canvas.print_png('test.png')

# %%
# %%html
# <img src='test.png'/>
# Out:
# <img src='test.png'/>

# %%
plt.figure()#to create figure
plt.plot(3,2,'.')
ax=plt.gca()
ax.axis([0,6,0,10])
# Out:
# [0, 6, 0, 10]

# %%
#create a newfigure
plt.plot(1.5,1.5,'.')
plt.plot(2,2,'.')
plt.plot(2.5,2.5,'.')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold">
# SCATTER Function</p>

# %%
import numpy as np
x=np.array([1,2,3,4,5,6,7,8])
y=x
plt.figure()
plt.scatter(x,y)  #similar to plt.plote but function is changed
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import numpy as np
x=np.array([1,2,3,4,5,6,7,8])
y=x
colors=['green']*(len(x)-1)
colors.append('red')
plt.figure()
#plt.figure

plt.scatter(x,y, s=100,c=colors)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
